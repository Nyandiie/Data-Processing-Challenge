# %% [markdown]
# # Data Processing (70%)

# %% [markdown]
# Using standard python (No pandas / seaborn) with default libraries (os, sys, time, json, csv, …)

# %% [markdown]
# 7 tasks

# %%
import csv
import json
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Task 1 - Read in the provided ACW Data using the CSV library.

# %%
#FINAL ANSWER
with open("acw_user_data.csv" , mode = "r" ) as csvFile : #file has been read
    print(csvFile)
    print(type(csvFile))
# Out:
# <_io.TextIOWrapper name='acw_user_data.csv' mode='r' encoding='cp1252'>
# <class '_io.TextIOWrapper'>

# %%
### the following cells are a review of Week 3 material/workshops and some that helped me better understand the data set

# %%
#the following cells are a review of Week 3 material/workshops
#and some that helped me better understand the data set

with open("acw_user_data.csv" , mode = "r" ) as csvFile :
    csv_reader = csv.reader( csvFile, delimiter=',' )
    for line_number, line in enumerate(csv_reader):
        print(line_number, line)
# Out:
# 0 ['Address Street', 'Address City', 'Address Postcode', 'Age (in Years)', 'Distance Commuted to Work (in Km)', 'Employer Company', 'Credit Card Start Date', 'Credit Card Expiry Date', 'Credit Card Number', 'Credit Card CVV', 'Dependants', 'First Name', 'Bank IBAN Number', 'Last Name', 'Marital Status', 'Yearly Pension (in Dollars)', 'Retired', 'Yearly Salary (in Dollars)', 'Sex', 'Vehicle Make', 'Vehicle Model', 'Vehicle Year', 'Vehicle Type']
# 1 ['70 Lydia isle', 'Lake Conor', 'S71 7XZ', '89', '0', 'N/A', '08/18', '11/27', '676373692463', '875', '3', 'Kieran', 'GB62PQKB71416034141571', 'Wilson', 'married or civil partner', '7257', 'True', '72838', 'Male', 'Hyundai', 'Bonneville', '2009', 'Pickup']
# 2 ['00 Wheeler wells', 'Chapmanton', 'L2 7BT', '46', '13.72', 'Begum-Williams', '08/12', '11/26', '4529436854129855', '583', '1', 'Jonathan', 'GB37UMCO54540228728019', 'Thomas', 'married or civil partner', '0', 'False', '54016', 'Male', 'Nissan', 'ATS', '1996', 'Coupe']
# 3 ['Studio 33K Joel walk', 'Randallborough', 'ME3N 1GH', '22', '16.02', 'Hill-Wright', '11/19', '07/27', '4091726363083888495', '422', '1', 'Antony', 'GB40CVUE84011545859591', 'Jones', 'married or civil partner', '0', 'False', '68049', 'Male', 'GMC', 'Achieva', '2015', 'Convertible, Coupe']
# 4 ['Studio 46S Bethany lights', 'East Reece', 'E10 9RJ', '56', '19.35', 'Green LLC', '10/17', '04/18', '4671332769487632633', '669', '2', 'Henry', 'GB40YPKK71613332239280', 'Shaw', 'married or civil partner', '0', 'False', '91337', 'Male', 'Scion', 'F150 SuperCrew Cab', '1994', 'Pickup']
# 5 ['Flat 3 Christine views', 'Fletcherstad', 'WS2 9SN', '57', '5.94', 'Hill, Evans and Harrison', '04/19', '11/27', '2245094149128526', '659', '2', 'Jodie', 'GB95WAYW31715898077181', "O'Brien", 'married or civil partner', '0', 'False', '18446', 'Female', 'Buick', 'Outback', '2020', 'SUV']
# 6 ['Studio 43M Emily rapid', 'West Derekborough', 'W1J 0DL', '23', '10.73', 'Gill and Sons', '03/15', '05/15', '4485214746578045493', '123', '3', 'Ryan', 'GB29SSDY05529526374313', 'Clarke', 'married or civil partner', '0', 'False', '38100', 'Male', 'Lexus', 'Paceman', '2004', 'Van/Minivan']
# 1000 ['Flat 9 Mohamed route', 'West Glen', 'LL3M 4WS', '80', '0', 'N/A', '12/14', '01/16', '180020306382110', '903', '1', 'Sheila', 'GB45ORXV49380519147072', 'Russell', 'single', '22869', 'True', '25788', 'Female', 'Geo', 'S7', '1993', 'Van/Minivan']

# %% [markdown]
# 0 ['Address Street', 'Address City', 'Address Postcode', 'Age (in Years)', 'Distance Commuted to Work (in Km)', 'Employer Company', 'Credit Card Start Date', 'Credit Card Expiry Date', 'Credit Card Number', 'Credit Card CVV', 'Dependants', 'First Name', 'Bank IBAN Number', 'Last Name', 'Marital Status', 'Yearly Pension (in Dollars)', 'Retired', 'Yearly Salary (in Dollars)', 'Sex', 'Vehicle Make', 'Vehicle Model', 'Vehicle Year', 'Vehicle Type']

# %%
with open("acw_user_data.csv" , mode = "r" ) as csvFile :
    csv_reader = csv.reader( csvFile, delimiter=',' )
    for line_number, line in enumerate(csv_reader):
        if line_number == 0 :
            continue
        print(line_number, line)
# Out:
# 1 ['70 Lydia isle', 'Lake Conor', 'S71 7XZ', '89', '0', 'N/A', '08/18', '11/27', '676373692463', '875', '3', 'Kieran', 'GB62PQKB71416034141571', 'Wilson', 'married or civil partner', '7257', 'True', '72838', 'Male', 'Hyundai', 'Bonneville', '2009', 'Pickup']
# 2 ['00 Wheeler wells', 'Chapmanton', 'L2 7BT', '46', '13.72', 'Begum-Williams', '08/12', '11/26', '4529436854129855', '583', '1', 'Jonathan', 'GB37UMCO54540228728019', 'Thomas', 'married or civil partner', '0', 'False', '54016', 'Male', 'Nissan', 'ATS', '1996', 'Coupe']
# 3 ['Studio 33K Joel walk', 'Randallborough', 'ME3N 1GH', '22', '16.02', 'Hill-Wright', '11/19', '07/27', '4091726363083888495', '422', '1', 'Antony', 'GB40CVUE84011545859591', 'Jones', 'married or civil partner', '0', 'False', '68049', 'Male', 'GMC', 'Achieva', '2015', 'Convertible, Coupe']
# 4 ['Studio 46S Bethany lights', 'East Reece', 'E10 9RJ', '56', '19.35', 'Green LLC', '10/17', '04/18', '4671332769487632633', '669', '2', 'Henry', 'GB40YPKK71613332239280', 'Shaw', 'married or civil partner', '0', 'False', '91337', 'Male', 'Scion', 'F150 SuperCrew Cab', '1994', 'Pickup']
# 5 ['Flat 3 Christine views', 'Fletcherstad', 'WS2 9SN', '57', '5.94', 'Hill, Evans and Harrison', '04/19', '11/27', '2245094149128526', '659', '2', 'Jodie', 'GB95WAYW31715898077181', "O'Brien", 'married or civil partner', '0', 'False', '18446', 'Female', 'Buick', 'Outback', '2020', 'SUV']
# 6 ['Studio 43M Emily rapid', 'West Derekborough', 'W1J 0DL', '23', '10.73', 'Gill and Sons', '03/15', '05/15', '4485214746578045493', '123', '3', 'Ryan', 'GB29SSDY05529526374313', 'Clarke', 'married or civil partner', '0', 'False', '38100', 'Male', 'Lexus', 'Paceman', '2004', 'Van/Minivan']
# 1000 ['Flat 9 Mohamed route', 'West Glen', 'LL3M 4WS', '80', '0', 'N/A', '12/14', '01/16', '180020306382110', '903', '1', 'Sheila', 'GB45ORXV49380519147072', 'Russell', 'single', '22869', 'True', '25788', 'Female', 'Geo', 'S7', '1993', 'Van/Minivan']

# %%
#remember context manager closes file, will need to be at top of every cell
with open("acw_user_data.csv" , mode = "r" ) as csvFile :
    csv_reader = csv.reader( csvFile, delimiter=',' )

    ages = []
    for line_number, line in enumerate(csv_reader):
        if line_number == 0 :
            continue
        

        ages.append( int(line[3]) ) 
        
    print("Ages: ", ages)
    mean_age = sum(ages)/len(ages) 
    print("Mean Age: ", mean_age)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[24], line 2
#       1 #remember context manager closes file, will need to be at top of every cell
# ----> 2 with open("acw_user_data.csv" , mode = "r" ) as csvFile :
#       3     csv_reader = csv.reader( csvFile, delimiter=',' )
#       5     ages = []
#
# File C:\Program Files\Python313\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# OSError: [Errno 22] Invalid argument: 'acw_user_data.csv'

# %%
headers =  ['Address Street', 'Address City', 'Address Postcode', 'Age (in Years)', 'Distance Commuted to Work (in Km)', 'Employer Company', 'Credit Card Start Date', 'Credit Card Expiry Date', 'Credit Card Number', 'Credit Card CVV', 'Dependants', 'First Name', 'Bank IBAN Number', 'Last Name', 'Marital Status', 'Yearly Pension (in Dollars)', 'Retired', 'Yearly Salary (in Dollars)', 'Sex', 'Vehicle Make', 'Vehicle Model', 'Vehicle Year', 'Vehicle Type']

for item in range(len(headers)) :
    x = headers[item]
    print(item , x)
# Out:
# 0 Address Street
# 1 Address City
# 2 Address Postcode
# 3 Age (in Years)
# 4 Distance Commuted to Work (in Km)
# 5 Employer Company
# 6 Credit Card Start Date
# 7 Credit Card Expiry Date
# 8 Credit Card Number
# 9 Credit Card CVV
# 10 Dependants
# 11 First Name
# 12 Bank IBAN Number
# 13 Last Name
# 14 Marital Status
# 15 Yearly Pension (in Dollars)
# 16 Retired
# 17 Yearly Salary (in Dollars)
# 18 Sex
# 19 Vehicle Make
# 20 Vehicle Model
# 21 Vehicle Year
# 22 Vehicle Type

# %%
#remember context manager closes file, will need to be at top of every cell
with open("acw_user_data.csv" , mode = "r" ) as csvFile :
    csv_reader = csv.reader( csvFile, delimiter=',' )

    vehicleMake = []
def func_1(csv_reader):
    VehicleMake = []
    for i in csv_reader:
        if line_number == 'True' :
            
        

        vehicleMake.append((line[19]) ) 
        
    print("Vehicle Make: ", vehicleMake)
# Out:
# Vehicle Make:  ['Hyundai', 'Nissan', 'GMC', 'Scion', 'Buick', 'Lexus', 'Lexus', 'Volvo', 'Volkswagen', 'Dodge', 'Volvo', 'Volkswagen', 'Ford', 'Lincoln', 'Nissan', 'Acura', 'Hyundai', 'Mercedes-Benz', 'Nissan', 'Chevrolet', 'Ford', 'MAZDA', 'Toyota', 'Mitsubishi', 'Chrysler', 'Dodge', 'Hyundai', 'Kia', 'N
chevrolet', 'INFINITI', 'Dodge', 'Chevrolet', 'Chevrolet', 'Volvo', 'Oldsmobile', 'Kia', 'INFINITI', 'BMW', 'BMW', 'Chevrolet', 'Audi', 'Honda', 'Audi', 'Toyota', 'Cadillac', 'Lotus', 'Ram', 'Mercury', 'Mercedes-Benz', 'Ford', 'GMC', 'BMW', 'Ford', 'Dodge', 'Nissan', 'Nissan', 'Mercury', 'Volvo', 'Ram', 'Land Rover', 'Chevrolet', 'Honda', 'Dodge', 'GMC', 'GMC', 'Suzuki', 'Mercedes-Benz', 'Buick', 'Cadillac', 'Ford', 'Jeep', 'Audi', 'BMW', 'Saab', 'Maserati', 'Ford', 'Mercedes-Benz', 'Toyota', 'Maybach', 'Hyundai', 'BMW', 'Ford', 'Lexus', 'Ford', 'Audi', 'INFINITI', 'Land Rover', 'Ford', 'Ford', 'Dodge', 'GMC', 'Dodge', 'Subaru', 'GMC', 'MAZDA', 'Chevrolet', 'BMW', 'Toyota', 'Mercury', 'INFINITI', 'Dodge', 'Chrysler', 'Dodge', 'MAZDA', 'MINI', 'Hyundai', 'Chevrolet', 'Lincoln', 'MINI', 'Chevrolet', 'Chevrolet', 'Mercedes-Benz', 'Honda', 'Kia', 'Pontiac', 'Ram', 'BMW', 'Volvo', 'Volkswagen', 'Toyota', 'Hyundai', 'Toyota', 'Mercury', 'Ford', 'GMC', 'Chevrolet', 'Volkswagen', 'BMW', 'Suzuki', 'Land Rover', 'Honda', 'Mercedes-Benz', 'Hyundai', 'GMC', 'Suzuki', 'Porsche', 'Chevrolet', 'Chevrolet', 'GMC', 'Kia', 'Acura', 'Suzuki', 'Toyota', 'GMC', 'Audi', 'Jaguar', 'Dodge', 'FIAT', 'Ford', 'Chevrolet', 'BMW', 'Porsche', 'Honda', 'Mercedes-Benz', 'Hyundai', 'Toyota', 'Buick', 'MAZDA', 'Chevrolet', 'Ford', 'Lexus', 'Eagle', 'Mercedes-Benz', 'Dodge', 'Ford', 'BMW', 'Chrysler', 'Lincoln', 'Nissan', 'Mercedes-Benz', 'Freightliner', 'Ford', 'Nissan', 'Kia', 'INFINITI', 'Ram', 'Volkswagen', 'MAZDA', 'BMW', 'Volkswagen', 'HUMMER', 'MINI', 'MINI', 'Linc ...

# %% [markdown]
# # Task 2

# %%
#FINAL ANSWER


#    Searches thru CSV file and categorizes information into lists of dictionaries.
    
#    Arg:
#        CSVArgument,, The file path to the CSV data.
        
#    Returns:
#        Three lists containing dictionaries for Vehicle, Bank, and Address details.
    

#input CSV as CSVArgument
def ExtractDataFunc( CSVArgument ) :
    VehicleDetailsList = []
    BankDetailsList = []
    AddressDetailsList = []

    #read CSV
    with open( CSVArgument , mode = "r" ) as CSVArgument_UserData :
        UserData_reader = csv.reader( CSVArgument_UserData )
        for row_number, row_item in enumerate(UserData_reader) :
            # Skip header row,,
            if row_number == 0 :
                continue
            else :
                # A - Vehicle Details,, cast int if necessary
                VehicleDetailsList.append({
                "Make" : row_item[19],
                "Model"  : row_item[20],
                "Year" : int(row_item[21]),
                "Type" : row_item[22],
                })

                # B - Bank Details,, cast int if necessary
                BankDetailsList.append({
                "Start Date" : row_item[6],                        #1
                "Expiry Date"  : row_item[7],                      #2
                "Credit Card Number" : int(row_item[8]),           #3
                "CVV" : int(row_item[9]),                               #4
                "IBAN Number" : row_item[12]                        #5
                })

                # C - Address Details
                AddressDetailsList.append({
                "Street": row_item[0] ,
                "City": row_item[1] ,
                "Postcode":  row_item[2] ,                
                })

    return VehicleDetailsList , BankDetailsList , AddressDetailsList

VehicleDict , BankDict, AddressDict = ExtractDataFunc("acw_user_data.csv")

# %%
def VehicleMake() :
    with open("acw_user_data.csv" , mode = "r" ) as UserData :
        vehicleMakeList = []
        UserData_reader = csv.reader( UserData, delimiter=',' )
        for row_number, row_item in enumerate(UserData_reader) :
            if row_number == 0 :
                continue
            else :
                vehicleMakeList.append(row_item[19])
    print(vehicleMakeList)

VehicleMake()

# %%
import csv
import json

#19 Vehicle Make
#20 Vehicle Model
#21 Vehicle Year
#22 Vehicle Type


def start() :
    # A - VehicleDetails
    vehicleMakeList = ExtractDetailsFunc(19)
    vehicleModelList = ExtractDetailsFunc(20)
    vehicleYearList = ExtractDetailsFunc(21)
    vehicleTypeList = ExtractDetailsFunc(22)

    # B - Bank Details
    ccStartDateList = ExtractDetailsFunc(6)
    ccExpiryDateList = ExtractDetailsFunc(7)
    ccNumberList = ExtractDetailsFunc(8)
    cc_CVVList =  ExtractDetailsFunc(9)
    bankIBANnumberList = ExtractDetailsFunc(12)


    # C - Address Details
    aStreetList = ExtractDetailsFunc(0)
    aCityList = ExtractDetailsFunc(1)
    aPostcode = ExtractDetailsFunc(2)

    VehicleDict = VehicleDictFunc(vehicleMakeList, vehicleModelList, vehicleYearList, vehicleTypeList)
    print(VehicleDict)


    with open("VehicleDetails.json", mode = "w") as VDJson :
        json.dump(VehicleDict , VDJson)

def ExtractDetailsFunc(rowNumberArgument) :
    with open("acw_user_data.csv" , mode = "r" ) as UserData :
        placeholderList = []
        UserData_reader = csv.reader( UserData, delimiter=',' )
        for row_number, row_item in enumerate(UserData_reader) :
            if row_number == 0 :
                continue
            else :
                placeholderList.append(row_item[rowNumberArgument])
    return placeholderList

def VehicleDictFunc(L1, L2, L3, L4 ) :
    fullDict = []
    for e1 in L1 :
        emptyDict = {}
        emptyDict.update({"Make" : e1})
        fullDict.append(emptyDict)
    for e2 in L2 :
        emptyDict = {}
        emptyDict.update({"Model" : e2})
        fullDict.append(emptyDict)
    for e3 in L3 :
        emptyDict = {}
        emptyDict.update({"Year" : e3})
        fullDict.append(emptyDict)
    for e4 in L4 :
        emptyDict = {}
        emptyDict.update({"Type" : e4})
        fullDict.append(emptyDict)
    return fullDict


start()

# %%
import json


names = ["Andie" , "Benji" , "Charlie" , "Dani" , "Ernie"]
Lnames = ["Munoz" , "Bravo" , "Contreras" , "Davidson" , "Erickson"]

result = zip (names , Lnames)
result = (dict(result))


with open("Names.json", mode = "w") as NameJSON :
#    json.dump(result , NameJSON)

# %%
names = ["Andie" , "Benji" , "Carlos" , "Daniel"]
lastname = ["Arigato" , "Bravo" , "Cox" , "David"]
pets = ["Alligator" , "Bird" , "Canary" , "Dolphin"]
city = ["Austin" , "Boulder" , "Clinton" , "Detroit"]


detailsList = []
for i1, i2, i3, i4 in zip(names, lastname, pets, city):
    dictionary = {}
    dictionary["Name"] = i1
    dictionary["Surname"] = i2
    dictionary["Pets"] = i3
    dictionary["Location"] = i4
    detailsList.append(dictionary)
print(detailsList)


import json

with open("TestNames.json", mode = "w") as NamesJSON :
#    json.dump(detailsList , NamesJSON)

# %%
#Not bad but I'm opening the file multiple different times and a lot of my functions are really only slightly different?
#there are probably some optimizations I can try doing...
#i will work with this and come back to it after i get to 5
#write to JSON funtion?

#Improvemnets TO DO:
# 1. Don't open file multiple times
# 2. JSON Function

#        ----------------------------------------

def start() :
    # A - VehicleDetails
    vehicleMakeList = ExtractDetailsFunc(19)
    vehicleModelList = ExtractDetailsFunc(20)
    vehicleYearList = ExtractDetailsFunc(21)
    vehicleTypeList = ExtractDetailsFunc(22)
    # make into a dictionary
    VehicleDict = VehicleDictFunc(vehicleMakeList , vehicleModelList, vehicleYearList, vehicleTypeList)

    #might as well check its output
    with open("VehicleDetails.json", mode = "w") as VehicleJSON :
        json.dump(VehicleDict , VehicleJSON)


    # B - Bank Details
    ccStartDateList = ExtractDetailsFunc(6)
    ccExpiryDateList = ExtractDetailsFunc(7)
    ccNumberList = ExtractDetailsFunc(8)
    cc_CVVList =  ExtractDetailsFunc(9)
    bankIBANnumberList = ExtractDetailsFunc(12)
    BankDict = BankDictFunc(ccStartDateList , ccExpiryDateList, ccNumberList, cc_CVVList, bankIBANnumberList)

    with open("BankDetails.json", mode = "w") as BankJSON :
        json.dump(BankDict , BankJSON)

    # C - Address Details
    aStreetList = ExtractDetailsFunc(0)
    aCityList = ExtractDetailsFunc(1)
    aPostcode = ExtractDetailsFunc(2)
    AddressDict = AddressDictFunc(aStreetList , aCityList, aPostcode)

    with open("AddressDetails.json", mode = "w") as AddressJSON :
        json.dump(AddressDict , AddressJSON)


    #modify so i can use this in Task 4
    return VehicleDict, BankDict, AddressDict 

    
def ExtractDetailsFunc(rowNumberArgument) :
    with open("acw_user_data.csv" , mode = "r" ) as UserData :
        placeholderList = []
        UserData_reader = csv.reader( UserData, delimiter=',' )
        for row_number, row_item in enumerate(UserData_reader) :
            if row_number == 0 :
                continue
            else :
                placeholderList.append(row_item[rowNumberArgument])
    return placeholderList

def VehicleDictFunc(L1, L2, L3, L4 ) :
    VehicleDetailsList = []
    for i1, i2, i3, i4 in zip(L1, L2, L3, L4 ):
        dictionary = {}
        dictionary["Make"] = i1
        dictionary["Model"] = i2
        dictionary["Year"] = int(i3)
        dictionary["Type"] = i4
        VehicleDetailsList.append(dictionary)
    return VehicleDetailsList

def BankDictFunc(L1, L2, L3, L4 , L5 ) :
    BankDetailsList = []
    for i1, i2, i3, i4 , i5 in zip(L1, L2, L3, L4 , L5):
        dictionary = {}
        dictionary["Start Date"] = i1
        dictionary["Expiry Date"] = i2
        dictionary["Credit Card Number"] = int(i3)
        dictionary["CVV"] = int(i4)
        dictionary["IBAN Number"] = i5
        BankDetailsList.append(dictionary)
    return BankDetailsList

def AddressDictFunc(L1, L2, L3,) :
    AddressDetailsList = []
    for i1, i2, i3 in zip(L1, L2, L3):
        dictionary = {}
        dictionary["Street"] = i1
        dictionary["City"] = i2
        dictionary["Postcode"] = i3
        AddressDetailsList.append(dictionary)
    return AddressDetailsList


VehicleDict, BankDict, AddressDict = start()

# %%
def ExtractDataFunc( CSVArgument ) :
    VehicleDetailsList = []

    with open( CSVArgument , mode = "r" ) as CSVArgument_UserData :
        UserData_reader = csv.reader( CSVArgument_UserData )
        for row_number, row_item in enumerate(UserData_reader) :
            if row_number == 0 :
                continue
            else :
                # A - Vehicle Details
                VehicleDetailsList.append({
                "Make" : row_item[19],
                "Model"  : row_item[20],
                "Year" : int(row_item[21]),
                "Type" : row_item[22],
                })
        
    print(VehicleDetailsList)

ExtractDataFunc("acw_user_data.csv")
# Out:
# [{'Make': 'Hyundai', 'Model': 'Bonneville', 'Year': 2009, 'Type': 'Pickup'}, {'Make': 'Nissan', 'Model': 'ATS', 'Year': 1996, 'Type': 'Coupe'}, {'Make': 'GMC', 'Model': 'Achieva', 'Year': 2015, 'Type': 'Convertible, Coupe'}, {'Make': 'Scion', 'Model': 'F150 SuperCrew Cab', 'Year': 1994, 'Type': 'Pickup'}, {'Make': 'Buick', 'Model': 'Outback', 'Year': 2020, 'Type': 'SUV'}, {'Make': 'Lexus', 'Model': 'Paceman', 'Year': 2004, 'Type': 'Van/Minivan'}, {'Make': 'Lexus', 'Model': 'S-Series', 'Year': 1998, 'Type': 'Van/Minivan'}, {'Make': 'Volvo', 'Model': 'Express 3500 Passenger', 'Year': 2013, 'Type': 'SUV'}, {'Make': 'Volkswagen', 'Model': 'Town & Country', 'Year': 2010, 'Type': 'Sedan, Coupe, Hatchback'}, {'Make': 'Dodge', 'Model': 'Impreza', 'Year': 2015, 'Type': 'Sedan'}, {'Make': 'Volvo', 'Model': 'Tundra Double Cab', 'Year': 2011, 'Type': 'Sedan'}, {'Make': 'Volkswagen', 'Model': 'Stratus', 'Year': 2012, 'Type': 'SUV'}, {'Make': 'Ford', 'Model': '1500 Regular Cab', 'Year': 2008, 'Type': 'Convertible'}, {'Make': 'Lincoln', 'Model': 'Sierra 2500 HD Crew Cab', 'Year': 2016, 'Type': 'Pickup'}, {'Make': 'Nissan', 'Model': 'LC', 'Year': 2012, 'Type': 'SUV'}, {'Make': 'Acura', 'Model': 'S10 Regular Cab', 'Year': 1999, 'Type': 'Pickup'}, {'Make': 'Hyundai', 'Model': 'Colorado Extended Cab', 'Year': 2017, 'Type': 'Sedan'}, {'Make': 'Mercedes-Benz', 'Model': 'RX', 'Year': 1992, 'Type': 'Hatchback, Convertible'}, {'Make': 'Nissan', 'Model': 'Ram 3500 Quad Cab', 'Year': 2019, 'Type': 'Wagon, Sedan'}, {'Make': 'Chevrolet', 'Model': 'Nav
# %% [markdown]
# # Task 3
#
#
# The client informs you that they have had difficulty with errors in the dependants column. Some entries are empty (i.e. “ “ or “”), which may hinder your conversion from Task 2. These should be changed into something meaningful when encountered.

# %%
#FINAL ANSWER pt.1

# Search CSV to find rows with missing 'Dependants' data
# verify the scale of the data quality issue before fix

# no none types so i can assume that “ “ or “” are my only issues

with open("acw_user_data.csv" , mode = "r" ) as UserData :
    UserData_reader = csv.reader( UserData, delimiter=',' )
    problematicRows = []
    for row_number, row_item in enumerate(UserData_reader) :
        if row_number == 0 :
            continue
        elif row_item[10] == "" or row_item[10] == " " :
            problematicRows.append(row_number)
print(f"Problematic entries found at: {problematicRows}")
# Out:
# Problematic entries found at: [22, 110, 180, 206, 271, 273, 275, 359, 461, 469, 580, 637, 680, 726, 823, 866, 918, 932, 984]

# %%
# FINAL ANSWER pt.2


# Data Clean
# replace empty 'Dependants' entries with "0" 


UserDataFull = []

with open("acw_user_data.csv" , mode = "r", newline='' ) as UserData :
    UserData_reader = csv.reader( UserData, delimiter=',' )
    for row_number, row_item in enumerate(UserData_reader) :
        if row_item[10] == "" or row_item[10] == " " :
            row_item[10] = "0"
            UserDataFull.append(row_item)
        else :
            UserDataFull.append(row_item)
            
# Save the cleaned dataset to a new file ("AA_acw_user_data.csv")
# preserves original data
with open("AA_acw_user_data.csv" , mode = "w" , newline='') as UserDataCopy :
    UserData_writer = csv.writer( UserDataCopy, delimiter=',' )
    UserData_writer.writerows(UserDataFull)

#had to explicitly write " newline = '' " otherwise empty lists would be created inbetween

# %%
with open("acw_user_data.csv" , mode = "r" ) as UserData :
    UserData_reader = csv.reader( UserData, delimiter=',' )
    for row_item in UserData_reader :
        print(row_item[10])
# Out:
# Dependants
# 3
# 1
# 1
# 2
# 2
# 3
# 3
# 1
# 2
# 2
# 3
# 2
# 3
# 3
# 4
# 2
# 3
# 2
# 3
# 2
# 2
#
# 1
# 2
# 2
# 1
# 2
# 3
# 2
# 1
# 2
# 1
# 5
# 2
# 2
# 2
# 2
# 2
# 4
# 1
# 2
# 2
# 2
# 2
# 2
# 1
# 1
# 2
# 2
# 2
# 2
# 3
# 1
# 3
# 2
# 2
# 2
# 2
# 2
# 4
# 4
# 2
# 1
# 5
# 4
# 2
# 2
# 2
# 1
# 3
# 2
# 5
# 2
# 1
# 2
# 2
# 2
# 3
# 3
# 2
# 5
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 1
# 1
# 3
# 2
# 1
# 3
# 1
# 3
# 2
# 1
# 1
# 4
# 4
# 2
# 2
# 2
# 2
# 3
#
# 2
# 2
# 1
# 1
# 3
# 1
# 1
# 3
# 3
# 5
# 4
# 1
# 1
# 2
# 1
# 2
# 3
# 1
# 1
# 2
# 1
# 1
# 2
# 3
# 2
# 1
# 3
# 1
# 5
# 2
# 1
# 2
# 2
# 2
# 2
# 3
# 1
# 2
# 3
# 3
# 3
# 4
# 2
# 2
# 3
# 3
# 4
# 1
# 1
# 2
# 4
# 3
# 2
# 3
# 3
# 1
# 2
# 3
# 2
# 2
# 1
# 1
# 1
# 5
# 3
# 2
# 1
# 1
# 3
#
# 2
# 2
# 3
# 2
# 2
# 2
# 3
# 1
# 2
# 2
# 5
# 3
# 2
# 2
# 2
# 2
# 2
# 1
# 4
# 1
# 2
# 3
# 2
# 2
# 2
#
# 2
# 1
# 3
# 1
# 2
# 2
# 1
# 2
# 2
# 1
# 3
# 2
# 2
# 2
# 4
# 1
# 2
# 3
# 3
# 2
# 2
# 1
# 1
# 1
# 2
# 4
# 1
# 2
#
# 2
# 1
# 2
# 2
# 1
# 1
# 1
# 2
# 2
# 3
# 2
# 2
# 1
# 3
# 1

# %%
# worth checking if any none types are present

with open("acw_user_data.csv" , mode = "r" ) as UserData :
    UserData_reader = csv.reader( UserData, delimiter=',' )
    for row_number, row_item in enumerate(UserData_reader) :
        if row_number == 0 :
            continue
        elif row_item[10] is None :
            print(row_number , row_item[10])

# %%
# now i have to rewrite my code so it replaces the problematic entries with my chosen value "0"
# i will assume that whoever entered (or rather didn't) the data meant they have no dependents

with open("acw_user_data.csv" , mode = "a" ) as UserData :
    UserData_writer = csv.writer( UserData, delimiter=',' )
    for row_number, row_item in enumerate(UserData_reader) :
        if row_number == 0 :
            continue
        if row_item[10] == "" or row_item[10] == " " :
    
            row_item[10] = "0"
        print(row_number , row_item[10])
print(f"\nProblematic entries found at: {problematicRows}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 8
#       6 with open("acw_user_data.csv" , mode = "a" ) as UserData :
#       7     UserData_writer = csv.writer( UserData, delimiter=',' )
# ----> 8     for row_number, row_item in enumerate(UserData_writer) :
#       9         if row_number == 0 :
#      10             continue
#
# TypeError: '_csv.writer' object is not iterable

# %%
with open("acw_user_data-Copy1.csv" , mode = "a" ) as UserData :
    UserData_writer = csv.writer( UserData, delimiter=',' )
    for row_number, row_item in enumerate(UserData_writer) :
        if row_number == 0 :
            continue
        if row_item[10] == "" or row_item[10] == " " :
            row_item[10] = "0"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 with open("acw_user_data-Copy1.csv" , mode = "a" ) as UserData :
#       2     UserData_writer = csv.writer( UserData, delimiter=',' )
# ----> 3     for row_number, row_item in enumerate(UserData_writer) :
#       4         if row_number == 0 :
#       5             continue
#
# TypeError: '_csv.writer' object is not iterable

# %%
# now i have to rewrite my code so it replaces the problematic entries with my chosen value "0"
# i will assume that whoever entered (or rather didn't) the data meant they have no dependents

with open("acw_user_data.csv" , mode = "a" ) as UserData :
    UserData_writer = csv.writer( UserData, delimiter=',' )
    for row_number, row_item in enumerate(UserData_writer) :
        if row_number == 0 :
            continue
        if row_item[10] == "" or row_item[10] == " " :
            row_item[10] = "0"

#Problematic entries found at: [22, 110, 180, 206, 271, 273, 275, 359, 461, 469, 580, 637, 680, 726, 823, 866, 918, 932, 984]
#reader can only read, writer can only write by destroying the rest of the file, append can only add to the end of a file, cant be used together?
#maybe im meant to use the problematic list somehow?
#could i save it to a variable or something, then write them into the file?

# %%
zeroRows = []

with open("acw_user_data.csv" , mode = "r" ) as UserData :
    UserData_reader = csv.reader( UserData, delimiter=',' )
    for row_number, row_item in enumerate(UserData_reader) :
        if row_number == 0 :
            continue
            
        if row_item[10] == "" or row_item[10] == " " :
            row_item[10] = "0"
            zeroRows.append(row_item)
            
with open("acw_user_data_dependantscopy.csv" , mode = "w" ) as UserDataCopy :
    UserData_writer = csv.writer( UserDataCopy, delimiter=',' )
    UserData_writer.writerows(zeroRows)

#this creates a new file where my corrected problematic data is stored
#not quite but im close

# %%
with open("AA_acw_user_data.csv" , mode = "r" ) as UserData :
# Ford
# Buick
# Acura
# Hyundai
# Subaru
# Hyundai
# Nissan
# Hyundai
# Ford
# Cadillac
# Volkswagen
# GMC
# Porsche
# Toyota
# Pontiac
# Cadillac
# Nissan
# Jaguar
# Ford
# Lexus
# BMW
# GMC
# FIAT
# Land Rover
# Chevrolet
# Honda
# Dodge
# Mercedes-Benz
# Nissan
# GMC
# Kia
# Volkswagen
# Scion
# Suzuki
# Freightliner
# Volkswagen
# Jaguar
# Mercedes-Benz
# Nissan
# Saturn
# Toyota
# Ford
# Scion
# Geo

# %%
# okay so that is it for task 3

# %% [markdown]
# # Task 4

# %%
#FINAL ANSWER

#    Combine user data from CSV with Vehicle/Bank/Address Dict and export to JSON
def startTASK4() :
    GeneralDetailsList = []

    with open( "AA_acw_user_data.csv" , mode = "r" ) as CSVArgument_UserData :
        UserData_reader = csv.reader( CSVArgument_UserData )
        for row_number, row_item in enumerate(UserData_reader) :
            # skip header
            if row_number == 0 :
                continue
            else :
                #convert to int if necessary
                IndividualDict = {
                    "First Name": row_item[11],
                    "Last Name": row_item[13],
                    "Age": int(row_item[3]),
                    "Sex": row_item[18],
                    "Retired": row_item[16],
                    "Marital Status": row_item[14],
                    "Dependants": int(row_item[10]) ,
                    "Yearly Salary": float(row_item[17]),
                    "Yearly Pension": float(row_item[15]),
                    "Employer Company": row_item[5],
                    "Distance Commuted to Work (Km)": float(row_item[4]),
                    "Vehicle Details": VehicleDict[row_number -1],
                    "Bank Details": BankDict[row_number -1],
                    "Address Details": AddressDict[row_number -1]
                }
                GeneralDetailsList.append(IndividualDict)
#used [row_number - 1] to map the CSV row to the 0-indexed 
    
    #export to JSON
    with open( "processed.json" , mode = "w" ) as FullDetailsJSON :
        json.dump(GeneralDetailsList, FullDetailsJSON)
        
startTASK4()

# %%
myDetails = {
    "Name" : "Andie",
    "Age" : 23,
    "Location" : "Mexico"
}

favorites = {
    "Color" : "Red",
    "Animal" : "Deer",
    "Artist" : "Kasane Teto",
    "Food" : "Orange Chicken",
    "City" : "Paris",
}

myDetails["Favorites"] = favorites

#with open("myDetails.json", mode = "w") as myDetailsJSON :
#    json.dump(myDetails , myDetailsJSON)

# %%
#needs optimzization 
# file doesnt need to be opened multiple times
# GeneralDictFunc

def start() :
    
    FirstNameList = ExtractDetailsFunc(11)
    LastNameList = ExtractDetailsFunc(13)
    AgeList = ExtractDetailsFunc(3)
    SexList = ExtractDetailsFunc(18)
    RetiredList = ExtractDetailsFunc(16)
    MaritalStatusList = ExtractDetailsFunc(14)
    DependantsList = ExtractDetailsFunc(10)
    YearlySalaryList = ExtractDetailsFunc(17)
    YearlyPensionList = ExtractDetailsFunc(15)
    EmployerCompanyList = ExtractDetailsFunc(5)
    DistanceCommutedList = ExtractDetailsFunc(4)

    GeneralDict = GeneralDictFunc(
    FirstNameList,
    LastNameList,
    AgeList,
    SexList,
    RetiredList,
    MaritalStatusList,
    DependantsList,
    YearlySalaryList,
    YearlyPensionList,
    EmployerCompanyList,
    DistanceCommutedList,
    VehicleDict,
    BankDict,
    AddressDict)

    with open("processed.json", mode = "w") as GeneralJSON :
        json.dump(GeneralDict , GeneralJSON)

def ExtractDetailsFunc(rowNumberArgument) :
    with open("AA_acw_user_data.csv" , mode = "r" ) as UserData :
        placeholderList = []
        UserData_reader = csv.reader( UserData, delimiter=',' )
        for row_number, row_item in enumerate(UserData_reader) :
            if row_number == 0 :
                continue
            else :
                placeholderList.append(row_item[rowNumberArgument])
    return placeholderList


def GeneralDictFunc(L1, L2, L3, L4 , L5, L6, L7, L8, L9, L10, L11, D1,D2,D3) :
    GeneralDetailsList = []
    for i1, i2, i3, i4 , i5, i6, i7, i8, i9, i10, i11, di1, di2, di3 in zip(L1, L2, L3, L4 , L5, L6, L7, L8, L9, L10, L11, D1,D2,D3):
        dictionary = {}
        dictionary["First Name"] = i1
        dictionary["Last Name"] = i2
        dictionary["Age"] = int(i3)
        dictionary["Sex"] = i4
        dictionary["Retired"] = i5
        dictionary["Marital Status"] = i6
        dictionary["Dependants"] = int(i7)
        dictionary["Yearly Salary"] = float(i8)
        dictionary["Yearly Pension"] = float(i9)
        dictionary["Employer Company"] = i10
        dictionary["Distance Commuted to Work (Km)"] = float(i11)
        dictionary["Vehicle Details"] = di1
        dictionary["Bank Details"] = di2
        dictionary["Address Details"] = di3

        GeneralDetailsList.append(dictionary)
    return GeneralDetailsList


start()

# %% [markdown]
# # Task 5

# %%
#FINAL ANSWER


#    Reads processed user data and categorizes individuals into separate 
#    dictionaries based on their retirement status.


#11 First Name
#13 Last Name
#16 Retired    expressed as True or False


def EmplotmentStatusFunc() :
    with open("AA_acw_user_data.csv" , mode = "r" ) as UserData :
        UserData_reader = csv.reader( UserData, delimiter=',' )

        RetiredDict = {}
        EmployedDict = {}
        
        for row_number, row_item in enumerate(UserData_reader) :
            #skip header
            if row_number == 0 :
                continue
                
             # check 'Retired' status at index 16
             # if True, add to the retired dictionary; else, add to employed   
            if row_item[16] == "True"  :
                # combine first and last name to create key for dictionaries
                EmployeeName = (row_item[11] + " " + row_item[13])
                RetiredDict[EmployeeName] = "Retired"
            else :
                EmployeeName = (row_item[11] + " " + row_item[13])
                EmployedDict[EmployeeName] = "Employed"
                
        #outputs retired json
        with open("retired.json", mode = "w") as RetiredJSON :
            json.dump(RetiredDict , RetiredJSON)

        #outputs emplyed json
        with open("employed.json", mode = "w") as EmployedJSON :
            json.dump(EmployedDict , EmployedJSON)

            
EmplotmentStatusFunc()

# %% [markdown]
# # Task 6

# %% [markdown]
# The client states that there may be some issues with credit card entries. Any customers that have more than 10 years between their start and end date need writing to a separate file, called remove_ccard.json, in the JSON data format. The client will manually deal with these later based on your output. They request that you write a function to help perform this, which accepts a single row from the CSV data, and outputs whether the row should be flagged. This can then be used when determining whether to write the current person to the remove_ccard file. Note the dates are shown in the format used on credit cards which is “MM/YY”.

# %%
#FINAL ANSWER pt. 1
# // this outputs flagged cards to JSON

def task6( ) :
    with open("AA_acw_user_data.csv" , mode = "r" ) as UserData :
        UserData_reader = csv.reader( UserData, delimiter=',' )
        problematicCardsDict = {}
        NewProblematicCardRows = []
        for rowNumber, rowItem in enumerate(UserData_reader) :
            #skip header
            if rowNumber == 0 :
                continue
            #call the date func using Start Date (index 6) and Expiry Date (index 7)
            if NewStandardizeDateFunc(rowItem[6], rowItem[7]) == True :
                # if card exceeds the 10-year limit, track row and owner
                NewProblematicCardRows.append(rowNumber)
                EmployeeName = (rowItem[11] + " " + rowItem[13])
                #description of status...
                problematicCardsDict[EmployeeName] = f"card at row {rowNumber} has been flagged"
            else :
                continue
            #output flagged entries to JSON
        with open("remove_ccard.json", mode = "w") as CardJSON :
            json.dump(problematicCardsDict , CardJSON)
            


def NewStandardizeDateFunc(startDate, endDate) :
#    Calculates the duration between two dates in months.
#    Returns True if the duration is over 120 months (10 years).
    
        # split "MM/YY" string into a list [MM, YY],, convert year to months
        startDate = startDate.split("/")
        months = int(startDate[0])
        YearInMonths = (int(startDate[1]) + 2000) * 12
        totalValueinMonthsStart = YearInMonths + months

        endDate = endDate.split("/")
        months = int(endDate[0])
        YearInMonths = (int(endDate[1]) + 2000) * 12
        totalValueinMonthsEnd = YearInMonths + months

        TrueTotalValueinMonths = totalValueinMonthsEnd - totalValueinMonthsStart
    
    # flag cards valid for more than 10 years (120 months)
        if TrueTotalValueinMonths > 120 :
            return True
        
    
task6( )

# %%
#FINAL ANSWER pt.2
# // this is the tool to be used by the client


#    Search CSV for specific row index and validates the 
#    credit card dates for that specific entry.

def task6part2( rowNumberArgument ) :
        with open("AA_acw_user_data.csv" , mode = "r" ) as UserData :
            UserData_reader = csv.reader( UserData, delimiter=',' )

            for rowNumber, rowItem in enumerate(UserData_reader) :
                # target only row requested by client
                if rowNumber == rowNumberArgument :
                    startDate = rowItem[6]
                    endDate = rowItem[7]

                    # check if this specific card meets the 10-year condition
                    if NewStandardizeDateFunc(startDate, endDate) == True :
                        print("Entry at row number: ", rowNumber, "should be flagged")
                        return True # stop searching and return result
                    else :
                        print("Entry at row number: ", rowNumber, "should NOT be flagged")
                        return False




#not necessary to add function here,, but did so for clarity's sake
def NewStandardizeDateFunc(startDate, endDate) :
#    Calculates the duration between two dates in months.
#    Returns True if the duration is over 120 months (10 years).
        startDate = startDate.split("/")
        months = int(startDate[0])
        YearInMonths = (int(startDate[1]) + 2000) * 12
        totalValueinMonthsStart = YearInMonths + months

        endDate = endDate.split("/")
        months = int(endDate[0])
        YearInMonths = (int(endDate[1]) + 2000) * 12
        totalValueinMonthsEnd = YearInMonths + months

        TrueTotalValueinMonths = totalValueinMonthsEnd - totalValueinMonthsStart

        if TrueTotalValueinMonths > 120 :
            return True
        


# User Input Loop
# use 'while True' to keep the program running until user provides a valid row number
while True :
    try :
        # request a specific record index from the client
        clientInput = input("Enter row number: ")
        rowNumberArgument = int(clientInput)    # Attempt to convert input to an integer
        if rowNumberArgument < 0:   #Row indices must be positive integers
            print("Row numbers cannot be negative")
            continue
        value = task6part2( rowNumberArgument )
        # if function finishes the file without finding the row, 'value' will be None
        if value == None  :
            print("Row not in file.")
        else:
            break #exit loop if valid input found

    except ValueError:
        print("Invalid input, please input only a number.")    
        # catch error cases where the user types text instead of a number
# Out:
# Enter row number:  -9
# Row numbers cannot be negative
# Enter row number:  nine
# Invalid input, please input only a number.
# Enter row number:  999999
# Row not in file.
# Enter row number:  9
# Entry at row number:  9 should NOT be flagged

# %% [markdown]
# ### Procedure 6

# %%
# files up to task 5 have been optimized

# %%
# okay how do i do this, sequentially i need to 
#1. writ a function, 
#    input: rrow from CSV
#    output: RowNumber, "Row flagged."  // Outputs a JSON with all flagged rows.

# Any customers that have more than 10 years between their start and end date
#2. That function would need to calculate (end date - start date) and if it is 10 years or more it should be flagged
# how can this be calculated ? MM/YY format
#can i assume that the start date for all is sometime after the 2000's ?

# %%
with open( "AA_acw_user_data.csv" , mode = "r" ) as CSVArgument_UserData :
    UserData_reader = csv.reader( CSVArgument_UserData )
    for row_number, row_item in enumerate(UserData_reader) :
        if row_number == 0 :
            continue

        elif row_item[6] :
            YY = row_item[6].split("/")
            YY = int(YY[1])
            if YY > 30 :
                print(YY)

#okay so i can correctly assume that all credit cards were issued this century

# what about the months, is 10 and 1 month also to be flagged? i guess so, what if it is exactly 10?

# ". Any customers that have more than 10 years between their start and end date" // so if it's exactly ten no?
# strictly speaking, if ts exactly 10 it shouldn't be flagged, only values that are 10 and 1 month + should be flagged
#this makes it more difficult...

#it may be easier if i just deal with the months
# if there is a difference that is difference > 120 months it should be flagged

# %%
#good start but requirements are yet to be met
#can be more efficient

def task6( rowNumberArgument ) :
    ExtractDetailsFunc(rowNumberArgument)


def ExtractDetailsFunc(rowNumberArgument) :
    with open("acw_user_data.csv" , mode = "r" ) as UserData :
        placeholderList = []
        UserData_reader = csv.reader( UserData, delimiter=',' )
        for row_number, row_item in enumerate(UserData_reader) :
            if row_number == 0 :
                continue
            else :
                placeholderList.append(row_item[rowNumberArgument])
    return placeholderList

def StandardizeDateFunc( DatesList ) :
    DateInMonths = []
    for date in DatesList :
        newDate = date.split("/")
        months = int(newDate[0])
        YearInMonths = (int(newDate[1]) + 2000) * 12
        totalValueinMonths = YearInMonths + months
        DateInMonths.append(totalValueinMonths)
    return DateInMonths

sYYList = ExtractDetailsFunc(6)
eYYList = ExtractDetailsFunc(7)

StartinMonths = StandardizeDateFunc(sYYList)
EndinMonths = StandardizeDateFunc(eYYList)


ProblematicCardRows = []
for number, item in enumerate(EndinMonths) :
    DifferenceinMonths = EndinMonths[number] - StartinMonths[number]
    if DifferenceinMonths > 120 :
        ProblematicCardRows.append(number)
        print(number, DifferenceinMonths)
print(ProblematicCardRows)
print(len(ProblematicCardRows), "Problematic entries")
# Out:
# 1 171
# 6 200
# 7 141
# 15 178
# 23 138
# 30 140
# 32 126
# 34 145
# 35 163
# 40 141
# 41 140
# 51 149
# 52 125
# 53 131
# 55 152
# 56 134
# 63 167
# 68 133
# 72 142
# 75 147
# 76 158
# 81 138
# 85 201
# 86 162
# 87 171
# 91 199
# 101 144
# 106 166
# 110 129
# 113 176
# 114 158
# 117 137
# 122 152
# 133 166
# 134 154
# 136 123
# 137 182
# 142 152
# 147 193
# 155 159
# 161 127
# 164 190
# 168 153
# 178 170
# 179 169
# 182 134
# 190 139
# 193 124
# 198 143
# 201 145
# 218 126
# 220 165
# 226 145
# 229 132
# 230 139
# 235 151
# 247 135
# 251 178
# 252 171
# 260 125
# 261 127
# 263 128
# 265 205
# 271 135
# 276 170
# 281 144
# 286 135
# 287 132
# 298 147
# 305 158
# 308 153
# 310 191
# 311 153
# 313 186
# 317 129
# 318 150
# 319 151
# 321 135
# 327 143
# 328 163
# 329 124
# 330 134
# 331 156
# 344 193
# 346 127
# 347 123
# 349 129
# 351 161
# 357 123
# 362 156
# 364 165
# 370 137
# 377 155
# 389 140
# 390 131
# 391 159
# 393 163
# 396 205
# 399 175
# 403 192
# 405 128
# 408 163
# 412 154
# 413 159
# 418 149
# 421 126
# 422 155
# 424 145
# 433 127
# 434 136
# 438 158
# 446 150
# 449 176
# 452 140
# 454 132
# 464 128
# 467 122
# 468 130
# 474 141
# 476 195
# 481 145
# 485 121
# 492 132
# 497 161
# 498 160
# 500 176
# 504 180
# 505 147
# 507 123
# 511 186
# 512 138
# 514 138
# 516 134
# 520 163
# 528 173
# 530 172
# 531 173
# 540 165
# 551 148
# 552 141
# 554 129
# 564 130
# 566 127
# 573 213
# 574 122
# 586 182
# 588 154
# 594 141
# 596 175
# 599 153
# 604 149
# 606 173
# 607 134
# 611 121
# 620 123
# 622 178
# 626 173
# 627 139
# 629 127
# 630 157
# 643 131
# 647 155
# 655 193
# 658 132
# 663 139
# 664 134
# 670 141
# 673 123
# 694 164
# 697 127
# 698 127
# 709 158
# 712 148
# 715 129
# 716 156
# 719 161
# 721 140
# 737 179
# 742 128
# 749 125
# 750 205
# 752 146
# 755 134
# 756 153
# 761 180
# 767 172
# 769 167
# 776 155
# 777 121
# 778 128
# 779 124
# 780 176
# 781 192
# 782 128
# 784 143
# 786 150
# 791 146
# 792 158
# 795 155
# 800 130
# 805 145
# 808 135
# 814 199
# 815 140
# 816 131
# 824 142
# 826 178
# 829 186
# 841 123
# 842 122
# 856 122
# 857 126
# 858 191
# 860 183
# 875 129
# 876 133
# 878 130
# 879 206
# 880 145
# 895 130
# 897 170
# 898 188
# 899 129
# 900 170
# 901 132
# 905 122
# 906 144
# 909 132
# 912 139
# 913 145
# 920 152
# 921 156
# 927 175
# 931 127
# 932 188
# 933 143
# 935 135
# 936 133
# 941 134
# 949 135
# 952 149
# 963 123
# 968 155
# 978 124
# 979 138
# 984 167
# 987 129
# 988 134
# 990 212
# 994 133
# 996 194
# 997 196
# [1, 6, 7, 15, 23, 30, 32, 34, 35, 40, 41, 51, 52, 53, 55, 56, 63, 68, 72, 75, 76, 81, 85, 86, 87, 91, 101, 106, 110, 113, 114, 117, 122, 133, 134, 136, 137, 142, 147, 155, 161, 164, 168, 178, 179, 182, 190, 193, 198, 201, 218, 220, 226, 229, 230, 235, 247, 251, 252, 260, 261, 263, 265, 271, 276, 281, 286, 287, 298, 305, 308, 310, 311, 313, 317, 318, 319, 321, 327, 328, 329, 330, 331, 344, 346, 347, 349, 351, 357, 362, 364, 370, 377, 389, 390, 391, 393, 396, 399, 403, 405, 408, 412, 413, 418, 421, 422, 424, 433, 434, 438, 446, 449, 452, 454, 464, 467, 468, 474, 476, 481, 485, 492, 497, 498, 500, 504, 505, 507, 511, 512, 514, 516, 520, 528, 530, 531, 540, 551, 552, 554, 564, 566, 573, 574, 586, 588, 594, 596, 599, 604, 606, 607, 611, 620, 622, 626, 627, 629, 630, 643, 647, 655, 658, 663, 664, 670, 673, 694, 697, 698, 709, 712, 715, 716, 719, 721, 737, 742, 749, 750, 752, 755, 756, 761, 767, 769, 776, 777, 778, 779, 780, 781, 782, 784, 786, 791, 792, 795, 800, 805, 808, 814, 815, 816, 824, 826, 829, 841, 842, 856, 857, 858, 860, 875, 876, 878, 879, 880, 895, 897, 898, 899, 900, 901, 905, 906, 909, 912, 913, 920, 921, 927, 931, 932, 933, 935, 936, 941, 949, 952, 963, 968, 978, 979, 984, 987, 988, 990, 994, 996, 997]
# 252 Problematic entries

# %%
def task6( ) :
    with open("acw_user_data.csv" , mode = "r" ) as UserData :
        UserData_reader = csv.reader( UserData, delimiter=',' )
        NewProblematicCardRows = []
        for rowNumber, rowItem in enumerate(UserData_reader) :
            if rowNumber == 0 :
                continue
            if NewStandardizeDateFunc(rowItem[6], rowItem[7]) == True :
                NewProblematicCardRows.append(rowNumber)
            else :
                continue
        print(NewProblematicCardRows)
        print(len(NewProblematicCardRows), "problematic entries")


def StandardizeDateFunc( DatesList ) :
    DateInMonths = []
    for date in DatesList :
        newDate = date.split("/")
        months = int(newDate[0])
        YearInMonths = (int(newDate[1]) + 2000) * 12
        totalValueinMonths = YearInMonths + months
        DateInMonths.append(totalValueinMonths)
    return DateInMonths

def NewStandardizeDateFunc(startDate, endDate) :
        startDate = startDate.split("/")
        months = int(startDate[0])
        YearInMonths = (int(startDate[1]) + 2000) * 12
        totalValueinMonthsStart = YearInMonths + months

        endDate = endDate.split("/")
        months = int(endDate[0])
        YearInMonths = (int(endDate[1]) + 2000) * 12
        totalValueinMonthsEnd = YearInMonths + months

        TrueTotalValueinMonths = totalValueinMonthsEnd - totalValueinMonthsStart

        if TrueTotalValueinMonths > 120 :
            return True
        
task6( )
# Out:
# [2, 7, 8, 16, 24, 31, 33, 35, 36, 41, 42, 52, 53, 54, 56, 57, 64, 69, 73, 76, 77, 82, 86, 87, 88, 92, 102, 107, 111, 114, 115, 118, 123, 134, 135, 137, 138, 143, 148, 156, 162, 165, 169, 179, 180, 183, 191, 194, 199, 202, 219, 221, 227, 230, 231, 236, 248, 252, 253, 261, 262, 264, 266, 272, 277, 282, 287, 288, 299, 306, 309, 311, 312, 314, 318, 319, 320, 322, 328, 329, 330, 331, 332, 345, 347, 348, 350, 352, 358, 363, 365, 371, 378, 390, 391, 392, 394, 397, 400, 404, 406, 409, 413, 414, 419, 422, 423, 425, 434, 435, 439, 447, 450, 453, 455, 465, 468, 469, 475, 477, 482, 486, 493, 498, 499, 501, 505, 506, 508, 512, 513, 515, 517, 521, 529, 531, 532, 541, 552, 553, 555, 565, 567, 574, 575, 587, 589, 595, 597, 600, 605, 607, 608, 612, 621, 623, 627, 628, 630, 631, 644, 648, 656, 659, 664, 665, 671, 674, 695, 698, 699, 710, 713, 716, 717, 720, 722, 738, 743, 750, 751, 753, 756, 757, 762, 768, 770, 777, 778, 779, 780, 781, 782, 783, 785, 787, 792, 793, 796, 801, 806, 809, 815, 816, 817, 825, 827, 830, 842, 843, 857, 858, 859, 861, 876, 877, 879, 880, 881, 896, 898, 899, 900, 901, 902, 906, 907, 910, 913, 914, 921, 922, 928, 932, 933, 934, 936, 937, 942, 950, 953, 964, 969, 979, 980, 985, 988, 989, 991, 995, 997, 998]
# 252 problematic entries

# %%
#wait ahy are my problematic entreies lists different?

# %%
#well entry 2 and entry 7 are > 10 so my first attempt was incorrect

# %%
#1.    okay but i need to write one block of code that will output all sus entries into a json
#2.    but i also need to write a tool that allows the client to input a number and will tell them if its been flagged

# %%
# for 2 i could just write a loop that checks if the index is in a list with the indeces of the problematic rows
# but that would break if new data were to be added and i feel like its too easy so its probably not what is expected

# %%
def task6part2( rowNumberArgument ) :
        with open("AA_acw_user_data.csv" , mode = "r" ) as UserData :
            UserData_reader = csv.reader( UserData, delimiter=',' )

            for rowNumber, rowItem in enumerate(UserData_reader) :
                if rowNumber == rowNumberArgument :
                    startDate = rowItem[6]
                    endDate = rowItem[7]
                    if NewStandardizeDateFunc(startDate, endDate) == True :
                        print("Entry at row number: ", rowNumber, "should be flagged")
                        return True
                    else :
                        print("Entry at row number: ", rowNumber, "should NOT be flagged")
                        return False





def NewStandardizeDateFunc(startDate, endDate) :
        startDate = startDate.split("/")
        months = int(startDate[0])
        YearInMonths = (int(startDate[1]) + 2000) * 12
        totalValueinMonthsStart = YearInMonths + months

        endDate = endDate.split("/")
        months = int(endDate[0])
        YearInMonths = (int(endDate[1]) + 2000) * 12
        totalValueinMonthsEnd = YearInMonths + months

        TrueTotalValueinMonths = totalValueinMonthsEnd - totalValueinMonthsStart

        if TrueTotalValueinMonths > 120 :
            return True
        

task6part2( 5 )
# Out:
# Entry at row number:  5 should NOT be flagged
# False

# %%
def task6part2( rowNumberArgument ) :
        with open("AA_acw_user_data.csv" , mode = "r" ) as UserData :
            UserData_reader = csv.reader( UserData, delimiter=',' )

            for rowNumber, rowItem in enumerate(UserData_reader) :
                if rowNumber == rowNumberArgument :
                    startDate = rowItem[6]
                    endDate = rowItem[7]
                    if NewStandardizeDateFunc(startDate, endDate) == True :
                        print("Entry at row number: ", rowNumber, "should be flagged")
                        return True
                    else :
                        print("Entry at row number: ", rowNumber, "should NOT be flagged")
                        return False





def NewStandardizeDateFunc(startDate, endDate) :
        startDate = startDate.split("/")
        months = int(startDate[0])
        YearInMonths = (int(startDate[1]) + 2000) * 12
        totalValueinMonthsStart = YearInMonths + months

        endDate = endDate.split("/")
        months = int(endDate[0])
        YearInMonths = (int(endDate[1]) + 2000) * 12
        totalValueinMonthsEnd = YearInMonths + months

        TrueTotalValueinMonths = totalValueinMonthsEnd - totalValueinMonthsStart

        if TrueTotalValueinMonths > 120 :
            return True
        

task6part2( 5 )
# Out:
# Entry at row number:  5 should NOT be flagged
# False

# %%
#am i expected to use input() to allow the client to input the row number or should i assume he can input it into the function?

# %%
# if i do use input, that opens up the possibilty that the client might enter some text like "row 2" or something
# well that possibility is really always there, but im wondering if im going beyond what is expected by solving it
# uhhhhhh idk if im going extra

# %%
# i can try use a try/except or a loop

# %%
name = input()
print(name)
# Out:
#  me
# me

# %%
# whys it even print twice
# am i doing too much?

# %%
# if i have time ig ill come back to it

# %%
# i expected this to be much more time consuming than it really was...

# %%
def task6part2( rowNumberArgument ) :
        with open("AA_acw_user_data.csv" , mode = "r" ) as UserData :
            UserData_reader = csv.reader( UserData, delimiter=',' )

            for rowNumber, rowItem in enumerate(UserData_reader) :
                if rowNumber == rowNumberArgument :
                    startDate = rowItem[6]
                    endDate = rowItem[7]
                    if NewStandardizeDateFunc(startDate, endDate) == True :
                        print("Entry at row number: ", rowNumber, "should be flagged")
                        return True
                    else :
                        print("Entry at row number: ", rowNumber, "should NOT be flagged")
                        return False





def NewStandardizeDateFunc(startDate, endDate) :
        startDate = startDate.split("/")
        months = int(startDate[0])
        YearInMonths = (int(startDate[1]) + 2000) * 12
        totalValueinMonthsStart = YearInMonths + months

        endDate = endDate.split("/")
        months = int(endDate[0])
        YearInMonths = (int(endDate[1]) + 2000) * 12
        totalValueinMonthsEnd = YearInMonths + months

        TrueTotalValueinMonths = totalValueinMonthsEnd - totalValueinMonthsStart

        if TrueTotalValueinMonths > 120 :
            return True
        

while True :
    try :
        clientInput = input("Enter row number: ")
        rowNumberArgument = int(clientInput)
        task6part2( rowNumberArgument )
        break

    except ValueError:
        print("Invalid input, please input only a number.")
# Out:
# Enter row number:  9999

# %% [markdown]
# # Task 7

# %% [markdown]
# You have been tasked with calculating some additional metrics which will be used for ranking customers. You should create a new data attribute for our customers called “Salary-Commute”. Reading in from processed.json:

# %% [markdown]
# Add, and calculate appropriately, this new attribute. It should represent the Salary that a customer earns, per Km of their commute.
#
# Note: If a person travels 1 or fewer commute Km, then their salary-commute would be just their salary.
#
# B) Sort these records by that new metric, in ascending order.
#
# C) Store the output file out as a JSON format, for a commute.json file.

# %%
#FINAL ANSWER

def KeyFunc(employee):
# helper function used as sorting key
# it tells the sort() method to look specifically at the 'Salary/Commute' value
    return employee["Salary/Commute"]

with open("processed.json" , mode = "r" ) as ProcessedJSON :
    processed = json.load(ProcessedJSON)

    for employee in processed:
        Salary = employee["Yearly Salary"]
        Commute = employee["Distance Commuted to Work (Km)"]
        # if commute is 1km or less, use full salary
        if Commute <= 1:
            SalaryCommute = Salary
            employee["Salary/Commute"] = SalaryCommute
        else:
            # calculate salary earned per kilometer of commute
            SalaryCommute = (Salary/Commute)
            employee["Salary/Commute"] = SalaryCommute
    # sort the list of dictionaries in-place
    processed.sort(key = KeyFunc)

#save the updated and ranked data to JSON 
with open("commute.json" ,  mode = "w" ) as CommuteJSON :
    json.dump(processed, CommuteJSON)

# %%
# "Reading in from processed.json:..."
# ion remember how to read from a json? i was hoping i could read from memory

# %%
with open("processed.json" , mode = "r" ) as ProcessedJSON :
    data1 = json.load(ProcessedJSON)

    print(data1[2])
# Out:
# {'First Name': 'Antony', 'Last Name': 'Jones', 'Age': 22, 'Sex': 'Male', 'Retired': 'False', 'Marital Status': 'married or civil partner', 'Dependants': 1, 'Yearly Salary': 68049.0, 'Yearly Pension': 0.0, 'Employer Company': 'Hill-Wright', 'Distance Commuted to Work (Km)': 16.02, 'Vehicle Details': {'Make': 'GMC', 'Model': 'Achieva', 'Year': 2015, 'Type': 'Convertible, Coupe'}, 'Bank Details': {'Start Date': '11/19', 'Expiry Date': '07/27', 'Credit Card Number': 4091726363083888495, 'CVV': 422, 'IBAN Number': 'GB40CVUE84011545859591'}, 'Address Details': {'Street': 'Studio 33K Joel walk', 'City': 'Randallborough', 'Postcode': 'ME3N 1GH'}}

# %%
with open("processed.json" , mode = "r" ) as ProcessedJSON :
    processed = json.load(ProcessedJSON)

    for employee in processed:
        Salary = employee["Yearly Salary"]
        Commute = employee["Distance Commuted to Work (Km)"]

        print(Salary)
# Out:
# 72838.0
# 54016.0
# 68049.0
# 91337.0
# 18446.0
# 38100.0
# 96645.0
# 27964.0
# 63433.0
# 66157.0
# 39983.0
# 24062.0
# 97948.0
# 32281.0
# 59891.0
# 78214.0
# 86961.0
# 20918.0
# 40432.0
# 62377.0
# 83114.0
# 44434.0
# 79823.0
# 76038.0
# 78499.0
# 37866.0
# 70655.0
# 78955.0
# 92384.0
# 93744.0
# 58770.0
# 22959.0
# 80297.0
# 87308.0
# 70109.0
# 57953.0
# 46864.0
# 81220.0
# 63857.0
# 33987.0
# 24652.0
# 20206.0
# 96882.0
# 81215.0
# 19863.0
# 64885.0
# 59223.0
# 31412.0
# 18005.0
# 89661.0
# 87098.0
# 24329.0
# 97406.0
# 26452.0
# 17245.0
# 41981.0
# 75117.0
# 92899.0
# 59872.0
# 57934.0
# 55758.0
# 62907.0
# 76921.0
# 67367.0
# 44279.0
# 39466.0
# 89697.0
# 44472.0
# 90989.0
# 90740.0
# 79692.0
# 61470.0
# 51461.0
# 65036.0
# 66210.0
# 83864.0
# 82084.0
# 77566.0
# 47383.0
# 33081.0
# 42914.0
# 28041.0
# 45941.0
# 93472.0
# 98275.0
# 27443.0
# 56505.0
# 95658.0
# 47740.0
# 68019.0
# 17729.0
# 34869.0
# 95243.0
# 72536.0
# 19405.0
# 86434.0
# 65773.0
# 67005.0
# 48966.0
# 27904.0
# 54451.0
# 40184.0
# 84809.0
# 55803.0
# 22482.0
# 77914.0
# 49270.0
# 93469.0
# 26727.0
# 69158.0
# 25565.0
# 70759.0
# 97308.0
# 63388.0
# 37646.0
# 71402.0
# 79718.0
# 97270.0
# 31956.0
# 96782.0
# 75611.0
# 51225.0
# 69565.0
# 87281.0
# 45007.0
# 25474.0
# 72753.0
# 59855.0
# 74365.0
# 34106.0
# 95851.0
# 36832.0
# 57422.0
# 18127.0
# 26495.0
# 80283.0
# 18482.0
# 82960.0
# 32789.0
# 91415.0
# 80889.0
# 92248.0
# 53326.0
# 53418.0
# 82727.0
# 75219.0
# 85207.0
# 54094.0
# 93179.0
# 27629.0
# 92300.0
# 92943.0
        else:
            SalaryCommute = (Salary/Commute)
            employee["Salary/Commute"] = SalaryCommute

# %%
cars = [8, 2, -3]

cars.sort()

print(cars)
# Out:
# [-3, 2, 8]

# %%
def KeyFunc(employee):
    return employee["Salary/Commute"]

with open("processed.json" , mode = "r" ) as ProcessedJSON :
    processed = json.load(ProcessedJSON)

    for employee in processed:
        Salary = employee["Yearly Salary"]
        Commute = employee["Distance Commuted to Work (Km)"]
        if Commute <= 1:
            SalaryCommute = Salary
            employee["Salary/Commute"] = SalaryCommute
        else:
            SalaryCommute = (Salary/Commute)
            employee["Salary/Commute"] = SalaryCommute

    processed.sort(key = KeyFunc)

with open("commute.json" ,  mode = "w" ) as CommuteJSON :
    json.dump(processed, CommuteJSON)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Using Pandas and Seaborn
# Your client wishes to understand the data they have on their customers a bit more by use of visualisations. With use of Pandas and Seaborn read in the original CSV file provided with the assignment.
#
# 4 Tasks

# %% [markdown]
# ## Task 1

# %%
aws_df = pd.read_csv("acw_user_data.csv")

print(aws_df)
# Out:
#                 Address Street    Address City Address Postcode  \
# 0                70 Lydia isle      Lake Conor          S71 7XZ
# 1             00 Wheeler wells      Chapmanton           L2 7BT
# 2         Studio 33K Joel walk  Randallborough         ME3N 1GH
# 3    Studio 46S Bethany lights      East Reece          E10 9RJ
# 4       Flat 3 Christine views    Fletcherstad          WS2 9SN
# ..                         ...             ...              ...
# 995   Studio 6 Heather prairie    North Amelia           E9 0HB
# 996          Flat 3 Davies run      Greenshire           E7 4UJ
# 997     Flat 7 Barber motorway    Burrowsshire          L62 8TA
# 998              00 Tony forks       Abbiebury          NP4 1JL
# 999       Flat 9 Mohamed route       West Glen         LL3M 4WS
#
#      Age (in Years)  Distance Commuted to Work (in Km)  \
# 0                89                               0.00
# 1                46                              13.72
# 2                22                              16.02
# 3                56                              19.35
# 4                57                               5.94
# ..              ...                                ...
# 995              48                              18.44
# 996              22                              19.61
# 997              38                               6.66
# 998              45                              18.13
# 999              80                               0.00
#
#              Employer Company Credit Card Start Date Credit Card Expiry Date  \
# 0                         NaN                  08/18                   11/27
# 1              Begum-Williams                  08/12                   11/26
# 2                 Hill-Wright                  11/19                   07/27
# 3                   Green LLC                  10/17                   04/18
# 4    Hill, Evans and Harrison                  04/19                   11/27
# ..                        ...                    ...                     ...
# 995             Phillips-Pope                  04/19                   08/26
# 996                Hughes LLC                  05/12                   07/28
# 997              Bailey Group                  01/13                   05/29
# 998              Foster-Price                  04/19                   05/23
# 999                       NaN                  12/14                   01/16
#
#       Credit Card Number  Credit Card CVV  ...  Last Name  \
# 0           676373692463              875  ...     Wilson
# 1       4529436854129855              583  ...     Thomas
# 2    4091726363083888495              422  ...      Jones
# 3    4671332769487632633              669  ...       Shaw
# 4       2245094149128526              659  ...    O'Brien
# ..                   ...              ...  ...        ...
# 995     3563802099155576              908  ...      Clark
# 996     3591311819315276              675  ...      Jones
# 997     3584931475767707              679  ...     Walker
# 998     4090311300716168              775  ...    Thomson
# 999      180020306382110              903  ...    Russell
#
#                Marital Status Yearly Pension (in Dollars) Retired  \
# 0    married or civil partner                        7257    True
# 1    married or civil partner                           0   False
# 2    married or civil partner                           0   False
# 3    married or civil partner                           0   False
# 4    married or civil partner                           0   False
# ..                        ...                         ...     ...
# 995  married or civil partner                           0   False
# 996  married or civil partner                           0   False
# 997                    single                           0   False
# 998  married or civil partner                           0   False
# 999                    single                       22869    True
#
#     Yearly Salary (in Dollars)     Sex  Vehicle Make       Vehicle Model  \
# 0                        72838    Male       Hyundai          Bonneville
# 1                        54016    Male        Nissan                 ATS
# 2                        68049    Male           GMC             Achieva
# 3                        91337    Male         Scion  F150 SuperCrew Cab
# 4                        18446  Female         Buick             Outback
# ..                         ...     ...           ...                 ...
# 995                      84645    Male        Saturn         Convertible
# 996                      93314  Female        Toyota               Yukon
# 997                      20940  Female          Ford                  S6
# 998                      82412    Male         Scion   Ram 1500 Quad Cab
# 999                      25788  Female           Geo                  S7
#
#     Vehicle Year        Vehicle Type
# 0           2009              Pickup
# 1           1996               Coupe
# 2           2015  Convertible, Coupe
# 3           1994              Pickup
# 4           2020                 SUV
# ..           ...                 ...
# 995         2015         Van/Minivan
# 996         2015         Van/Minivan
# 997         2020               Sedan
# 998         2015              Pickup
# 999         1993         Van/Minivan
#
# [1000 rows x 23 columns]

# %%
print(type(aws_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(aws_df.columns)
# Out:
# Index(['Address Street', 'Address City', 'Address Postcode', 'Age (in Years)',
#        'Distance Commuted to Work (in Km)', 'Employer Company',
#        'Credit Card Start Date', 'Credit Card Expiry Date',
#        'Credit Card Number', 'Credit Card CVV', 'Dependants', 'First Name',
#        'Bank IBAN Number', 'Last Name', 'Marital Status',
#        'Yearly Pension (in Dollars)', 'Retired', 'Yearly Salary (in Dollars)',
#        'Sex', 'Vehicle Make', 'Vehicle Model', 'Vehicle Year', 'Vehicle Type'],
#       dtype='object')

# %%
aws_df.describe()
# Out:
#        Age (in Years)  Distance Commuted to Work (in Km)  Credit Card Number  \
# count     1000.000000                        1000.000000        1.000000e+03
# mean        54.302000                          10.457770        4.188020e+17
# std         21.319646                           6.951997        1.304208e+18
# min         18.000000                           0.000000        6.041600e+10
# 25%         36.000000                           5.637500        3.857314e+13
# 50%         54.000000                          12.170000        3.510666e+15
# 75%         72.000000                          16.262500        4.635909e+15
# max         91.000000                          20.340000        4.967327e+18
#
#        Credit Card CVV  Dependants  Yearly Pension (in Dollars)  \
# count      1000.000000  981.000000                  1000.000000
# mean        932.482000    2.135576                  5875.413000
# std        1626.125269    0.977799                 10986.507761
# min           2.000000    1.000000                     0.000000
# 25%         277.000000    1.000000                     0.000000
# 50%         559.500000    2.000000                     0.000000
# 75%         833.250000    3.000000                     0.000000
# max        9977.000000    5.000000                 46117.000000
#
#        Yearly Salary (in Dollars)  Vehicle Year
# count                 1000.000000   1000.000000
# mean                 57814.078000   2006.927000
# std                  23270.417139      8.211035
# min                  17046.000000   1992.000000
# 25%                  39089.750000   2000.000000
# 50%                  57518.000000   2008.000000
# 75%                  77211.500000   2014.000000
# max                  98915.000000   2020.000000

# %%
#FINAL ANSWER

SalaryColumn = aws_df["Yearly Salary (in Dollars)"]
AgeColumn = aws_df["Age (in Years)"]

print(SalaryColumn.mean())
print(AgeColumn.median())
# Out:
# 57814.078
# 54.0

# %% [markdown]
# ## Task 2

# %% [markdown]
# Perform univariate plots of the following data attributes:
# - A) Age, calculating how many bins would be required for a bin_width of 5.
# - B )Dependents, fixing data errors with seaborn itself.
# - C) Age (of default bins), conditioned on Marital Status

# %% [markdown]
# ### A)

# %%
sns.histplot(aws_df, x= "Age (in Years)", binwidth=5)
# Out:
# <Axes: xlabel='Age (in Years)', ylabel='Count'>

# %%
binNumber = (AgeColumn.max() - AgeColumn.min()) / 5

print(binNumber)
# i guess i round it to 15

binNumber = int(binNumber.round())
print(binNumber)
# Out:
# 14.6
# 15

# %%
Task2_a = sns.histplot(aws_df, x= "Age (in Years)", bins=binNumber).get_figure()

# %% [markdown]
# ### B) Dependents, fixing data errors with seaborn itself.

# %%
aws_df["Dependants"].unique()
# Out:
# array([ 3.,  1.,  2.,  4., nan,  5.])

# %%
aws_df["Dependants"] = aws_df["Dependants"].fillna(0)

# %%
aws_df["Dependants"].unique()
# Out:
# array([3., 1., 2., 4., 0., 5.])

# %%
aws_df["Dependants"] = aws_df["Dependants"].fillna(0).astype(int)

# %%
aws_df["Dependants"].unique()
# Out:
# array([3, 1, 2, 4, 0, 5])

# %%
Task2_b = sns.countplot(data=aws_df, x="Dependants").get_figure()

# %% [markdown]
# ### C) Age (of default bins), conditioned on Marital Status

# %%
Task2_c = sns.histplot(data = aws_df, x= "Age (in Years)", hue = "Marital Status", multiple="stack").get_figure()

# %% [markdown]
# ## Task 3

# %% [markdown]
# Perform multivariate plots with the following data attributes:
# - A) Commuted distance against salary.
# - B) Age against Salary
# - C) Age against Salary conditioned by Dependants

# %% [markdown]
# ### A) Commuted distance against salary.

# %%
Task3_a = sns.relplot(data=aws_df, x='Distance Commuted to Work (in Km)', y='Yearly Salary (in Dollars)', alpha=0.1)

# %%
# opacity jitter edited

# %% [markdown]
# ### B) Age against Salary

# %%
Task3_b = sns.relplot(data=aws_df, x='Age (in Years)', y='Yearly Salary (in Dollars)', alpha=0.7)

# %%
# opacity jitter edited

# %% [markdown]
# ### C) Age against Salary conditioned by Dependants

# %%
Task3_c = sns.relplot(data=aws_df, x='Age (in Years)', y='Yearly Salary (in Dollars)' ,  hue = "Dependants")

# %%
sns.relplot(data=aws_df, x='Age (in Years)', y='Yearly Salary (in Dollars)' ,  size = "Dependants", alpha=0.5)

# %%
# opacity jitter edited,, prefer previous tho

# %% [markdown]
# ## Task 4

# %%
figures_to_save ={
    "./Task2_A.png" : Task2_a,
    "./Task2_B.png" : Task2_b,
    "./Task2_C.png" : Task2_c,
    "./Task3_A.png" : Task3_a,
    "./Task3_B.png" : Task3_b,
    "./Task3_c.png" : Task3_c

}

# %%
for filename, handle in figures_to_save.items():
    handle.savefig(filename)

# %% [markdown]
# #### Other

# %%
# Additional parameters may be used to modify the plots to improve readability and information conveyance.
